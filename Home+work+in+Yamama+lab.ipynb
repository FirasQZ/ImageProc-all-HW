# %% [markdown]
# # I will present three photographs and extract histogram from them and i will analyze each one of them.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img1=cv2.imread('images/flower.pgm',0)
img2=cv2.imread('images/swan.pgm',0)
img3=cv2.imread('images/tools.pgm',0)

hist1=plt.hist(img1.ravel(),256,[0,256])
hist2=plt.hist(img2.ravel(),256,[0,256])
hist3=plt.hist(img3.ravel(),256,[0,256])

plt.subplot(231),plt.imshow(img1,'gray'),plt.title('flower.pgm')
plt.xticks([]), plt.yticks([])
plt.subplot(232),plt.imshow(img2,'gray'),plt.title('swan.pgm')
plt.xticks([]), plt.yticks([])
plt.subplot(233),plt.imshow(img3,'gray'),plt.title('tools.pgm')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # My histogram :
#
# # in First Histogram
# i am seeing number of pixel in this image is 1200 pixel, and range of the pixesls between 50 - 250 , also i sow such as ( number of pixel which the pixel value =100 is 1000 pixel and  number of pixel which the pixel value = 200 is 200 pixel ..... etc.
# so i the picture contain 2 color ( gray ) but the focus on the the value of pixel between (50 is hight to 120) and then start less from 150 to 200. ( hight contrast).
#
# # In secound Histogram
# this histogram describe the picture is (hight contrast) because pixel values are distributed and spread along the x-axis
# and the range is (20 - 255) this is very good On my own opinion. but the pixel value in white color it is 1200 more than any pixels.
#
#
# # In third Histogram

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img1=cv2.imread('images/flower.pgm',0)
img2=cv2.imread('images/swan.pgm',0)
img3=cv2.imread('images/tools.pgm',0)

plt.hist(img1.ravel(),256,[0,256]),plt.show();
plt.hist(img2.ravel(),256,[0,256]),plt.show();
plt.hist(img3.ravel(),256,[0,256]), plt.show();

# %% [markdown]
# # Otsu’s Binarization
# in simple words, it automatically calculates a threshold value from image histogram for a bimodal image.
# Then the algorithm finds the optimal threshold value and returns you as the second output.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img=cv2.imread('images/flower.pgm',0)
# global thresholding
ret1,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
# Otsu's thresholding
ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# Otsu's thresholding after Gaussian filtering
blur = cv2.GaussianBlur(img,(5,5),0)
ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# plot all the images and their histograms
images = [img, 0, th1,
          img, 0, th2,
          blur, 0, th3]
titles = ['Original Noisy Image','Histogram','Global Thresholding (v=127)',
          'Original Noisy Image','Histogram',"Otsu's Thresholding",
          'Gaussian filtered Image','Histogram',"Otsu's Thresholding"]
for i in range(3):
    plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
    plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
    plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
    plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img=cv2.imread('images/swan.pgm',0)
# global thresholding
ret1,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
# Otsu's thresholding
ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# Otsu's thresholding after Gaussian filtering
blur = cv2.GaussianBlur(img,(5,5),0)
ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# plot all the images and their histograms
images = [img, 0, th1,
          img, 0, th2,
          blur, 0, th3]
titles = ['Original Noisy Image','Histogram','Global Thresholding (v=127)',
          'Original Noisy Image','Histogram',"Otsu's Thresholding",
          'Gaussian filtered Image','Histogram',"Otsu's Thresholding"]
for i in range(3):
    plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
    plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
    plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
    plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # Adaptive

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('images/swan.pgm',0)
img = cv2.medianBlur(img,5)

ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,2)

titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]

for i in xrange(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()
