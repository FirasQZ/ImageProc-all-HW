# %% [markdown]
# # in this type of filtter it use laplac on the image so it is detrmain the edges about this picture  just picture (gray)
# First ... can use the sobel x it use to detrmain edges in direction X
# sobel y it use to detrmain edges in direction y
# in this Code the sobel can work same gousian blur to hide the nois. , and if inecrese the Ksize then show this edges is more clear.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('images/9.jpg',0)

laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=9)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=9)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('images/9.jpg',0)

laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=9)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=9)

imageadd1=np.add(img,laplacian)
imageadd2=np.subtract(img,laplacian)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(imageadd1,cmap = 'gray')
plt.title('Add image orginal with laplac'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(imageadd2,cmap = 'gray')
plt.title('Sub image orginal with laplac'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('images/9.jpg',0)

laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

imageadd1=np.subtract(img,laplacian)
imageadd2=np.subtract(img,sobelx)
imageadd3=np.subtract(img,sobely)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(imageadd1,cmap = 'gray')
plt.title('subtract image orginal with laplac'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(imageadd2,cmap = 'gray')
plt.title('subtract image orginal with Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(imageadd3,cmap = 'gray')
plt.title('subtract image orginal with Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('images/9.jpg',0)

laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=9)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=9)

imageadd1=np.add(img,laplacian)
imageadd2=np.add(img,sobelx)
imageadd3=np.add(img,sobely)
plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(imageadd1,cmap = 'gray')
plt.title('subtract image orginal with laplac'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(imageadd2,cmap = 'gray')
plt.title('subtract image orginal with Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(imageadd3,cmap = 'gray')
plt.title('subtract soble X with Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()
